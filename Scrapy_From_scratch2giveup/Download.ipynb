# %%
import os
from bs4 import BeautifulSoup
import requests

# %%
url = 'http://www.ngchina.com.cn/animals/'
url1 = 'http://www.ngchina.com.cn/science/'

# %%
html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml')  
img_ul = soup.find_all('ul',{'class':'img_list'})
os.makedirs('D://Computer_Vision/animals',exist_ok= True)

# %%
for ul in img_ul:
    imgs = ul.find_all('img')
    print(imgs)
    for img in imgs[1:]:
        url = img['src']
        print('\n',url)
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('D://Computer_Vision/animals/%s'% image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=128):
                f.write(chunk)
        print('Saved %s'%image_name)
# Out:
# [<img src=""/>, <img src="http://image.ngchina.com.cn/2020/0908/20200908034318849.jpg"/>, <img src="http://image.ngchina.com.cn/2020/0908/20200908102836119.jpg"/>]
#
#  http://image.ngchina.com.cn/2020/0908/20200908034318849.jpg
# Saved 20200908034318849.jpg
#
#  http://image.ngchina.com.cn/2020/0908/20200908102836119.jpg
# Saved 20200908102836119.jpg
# [<img src="http://image.ngchina.com.cn/2020/0902/20200902104629771.jpg"/>, <img src="http://image.ngchina.com.cn/2020/0831/20200831040357248.jpg"/>, <img src="http://image.ngchina.com.cn/2020/0826/20200826105827156.jpg"/>]
#
#  http://image.ngchina.com.cn/2020/0831/20200831040357248.jpg
# Saved 20200831040357248.jpg
#
#  http://image.ngchina.com.cn/2020/0826/20200826105827156.jpg
# Saved 20200826105827156.jpg

# %%
url2 = 'http://www.ngchina.com.cn/animals/photo/4807.html'

html = requests.get(url2).text
soup = BeautifulSoup(html, 'lxml')    
img_ul = soup.find_all('ul',{'class':'cf'})  #核心在于这里，这里直接决定了在网页中的什么地方进行操作
os.makedirs('D://Computer_Vision/animals',exist_ok= True)

# %%
for ul in img_ul:
    imgs = ul.find_all('img')
    print(imgs)
    for img in imgs[1:]:
        url = img['src']
        print('\n',url)
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('D://Computer_Vision/animals/%s'% image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=128):
                f.write(chunk)
        print('Saved %s'%image_name)
# Out:
# [<img src="http://image.ngchina.com.cn/2020/0820/thumb_469_352_20200820125856602.jpg" title="photo story" width="469px"/>, <img src="http://image.ngchina.com.cn/2020/0804/thumb_469_352_20200804053926903.jpg" title="photo story" width="469px"/>, <img src="http://image.ngchina.com.cn/2020/0724/thumb_469_352_20200724123618531.jpg" title="photo story" width="469px"/>, <img src="http://image.ngchina.com.cn/2020/0710/thumb_469_352_20200710013947724.jpg" title="photo story" width="469px"/>]
#
#  http://image.ngchina.com.cn/2020/0804/thumb_469_352_20200804053926903.jpg
# Saved thumb_469_352_20200804053926903.jpg
#
#  http://image.ngchina.com.cn/2020/0724/thumb_469_352_20200724123618531.jpg
# Saved thumb_469_352_20200724123618531.jpg
#
#  http://image.ngchina.com.cn/2020/0710/thumb_469_352_20200710013947724.jpg
# Saved thumb_469_352_20200710013947724.jpg
# ...

# %%
url2 = 'https://beautifulsoup.readthedocs.io/zh_CN/v4.4.0/'

html = requests.get(url2).text
soup = BeautifulSoup(html, 'lxml')    
img_ul = soup.find_all('img')  #核心在于这里，这里直接决定了在网页中的什么地方进行操作
os.makedirs('D://Computer_Vision/animals',exist_ok= True)

# %%
for img in img_ul:
    url = img['src']
    print('\n',url)
    r = requests.get(url, stream=True)
    image_name = url.split('/')[-1]
    with open('D://Computer_Vision/animals/%s'% image_name, 'wb') as f:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
    print('Saved %s'%image_name)
# Out:
#  http://www.crummy.com/software/BeautifulSoup/bs4/doc/_images/6.1.jpg
# Saved 6.1.jpg

# %%
url2 = 'http://www.ngchina.com.cn/news/9779.html'

html = requests.get(url2).text
soup = BeautifulSoup(html, 'lxml')    
img_ul = soup.find_all('img')  #核心在于这里，这里直接决定了在网页中的什么地方进行操作
os.makedirs('D://Computer_Vision/scraping_tests',exist_ok= True)

# %%
for img in img_ul[3:]:
    url = img['src']
    print('\n',url)
    r = requests.get(url, stream=True)
    image_name = url.split('/')[-1]
    with open('D://Computer_Vision/scraping_tests/%s'% image_name, 'wb') as f:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
    print('Saved %s'%image_name)
# Out:
#  http://image.ngchina.com.cn/2020/0820/thumb_469_352_20200820125856602.jpg
# Saved thumb_469_352_20200820125856602.jpg
#
#  http://image.ngchina.com.cn/2020/0804/thumb_469_352_20200804053926903.jpg
# Saved thumb_469_352_20200804053926903.jpg
#
#  http://image.ngchina.com.cn/2020/0724/thumb_469_352_20200724123618531.jpg
# Saved thumb_469_352_20200724123618531.jpg
#
#  http://image.ngchina.com.cn/2020/0710/thumb_469_352_20200710013947724.jpg
# Saved thumb_469_352_20200710013947724.jpg
#
#  http://image.ngchina.com.cn/2017/1024/20171024023609391.jpg
# Saved 20171024023609391.jpg
#
#  http://image.ngchina.com.cn/2018/0824/thumb_469_352_20180824054325356.jpg
# Saved thumb_469_352_20180824054325356.jpg
#
#  http://image.ngchina.com.cn/2018/0823/thumb_469_352_20180823054126855.jpg
# Saved thumb_469_352_20180823054126855.jpg
#
#  http://image.ngchina.com.cn/2018/0717/thumb_469_352_20180717055303642.jpg
# Saved thumb_469_352_20180717055303642.jpg
#
# ...
